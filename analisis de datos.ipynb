# %%
import pandas as pd

# %%
datos = pd.read_csv('CARS_1.csv')

# %%
datos.head(10)
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 0     Maruti Alto K10             51    Petrol                  998
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
# 5     Toyota Fortuner             99    Diesel                 2755
# 6       Hyundai Creta            731    Diesel                 1493
# 7          Tata Punch            381    Petrol                 1199
# 8     Mahindra Bolero            107    Diesel                 1498
# 9        Maruti Swift            205    Petrol                 1197
#
#    no_cylinder  seating_capacity transmission_type  fuel_tank_capacity  \
# 0            3               5.0         Automatic                27.0
# 1            4               5.0         Automatic                48.0
# ...

# %%
datos.tail(20)
# Out:
#                         car_name  reviews_count fuel_type  \
# 183       Mahindra Bolero Camper             88    Diesel
# 184            Tata Nexon EV Max              1  Electric
# 185          Mahindra Bolero Neo             97    Diesel
# 186          Mahindra Bolero Neo              1    Diesel
# 187               Audi e-tron GT              1  Electric
# 188      Maruti Swift Dzire Tour              1       CNG
# 189       Mercedes-Benz AMG A 35             21    Petrol
# 190      Mercedes-Benz GLC Coupe              5    Diesel
# 191                Toyota Glanza             23    Petrol
# 192                Toyota Glanza              3    Petrol
# 193        Porsche Cayenne Coupe              1    Petrol
# 194        Porsche Cayenne Coupe              6    Petrol
# 195            Honda City Hybrid              1    Petrol
# 196            Compass Trailhawk              1    Diesel
# 197                Jeep Meridian             78    Diesel
# ...

# %%
df1 = pd.DataFrame(datos)

# %%
df1

# %%
datitos = df1['fuel_type']=="Diesel"

# %%
print (datitos)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 198    False
# 199    False
# 200    False
# 201    False
# 202    False
# Name: fuel_type, Length: 203, dtype: bool

# %%
datos.shape
# Out:
# (203, 16)

# %%
datos.size
# Out:
# 3248

# %%
datos['fuel_type'].head(5)
# Out:
# 0    Petrol
# 1    Petrol
# 2    Petrol
# 3    Petrol
# 4    Petrol
# Name: fuel_type, dtype: object
