# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/argentina-provincial-data/argentina.csv

# %%
datos = pd.read_csv('../input/argentina-provincial-data/argentina.csv')

# %%
datos
# Out:
#                province           gdp  illiteracy    poverty  deficient_infra  \
# 0          Buenos Aires  2.926899e+08    1.383240   8.167798         5.511856
# 1             Catamarca  6.150949e+06    2.344140   9.234095        10.464484
# 2               Córdoba  6.936374e+07    2.714140   5.382380        10.436086
# 3            Corrientes  7.968013e+06    5.602420  12.747191        17.438858
# 4                 Chaco  9.832643e+06    7.517580  15.862619        31.479527
# 5                Chubut  1.774785e+07    1.548060   8.051752         8.044618
# 6            Entre Ríos  2.074341e+07    3.185580   7.288751        18.794568
# 7               Formosa  3.807057e+06    4.610640  17.035583        28.004985
# 8                 Jujuy  6.484938e+06    2.151390  13.367965        12.483179
# 9              La Pampa  6.990262e+06    1.539300   3.398774        16.505714
# 10             La Rioja  5.590516e+06    2.773210  10.875152         7.403254
# ...

# %%
datos['province']
# Out:
# 0            Buenos Aires
# 1               Catamarca
# 2                 Córdoba
# 3              Corrientes
# 4                   Chaco
# 5                  Chubut
# 6              Entre Ríos
# 7                 Formosa
# 8                   Jujuy
# 9                La Pampa
# 10               La Rioja
# 11                Mendoza
# 12               Misiones
# 13                Neuquén
# 14              Río Negro
# 15                  Salta
# 16               San Juan
# 17               San Luis
# 18             Santa Cruz
# 19               Santa Fe
# 20    Santiago del Estero
# 21                Tucumán
# Name: province, dtype: object

# %%
provincias = datos['province']
pobreza = datos['poverty']

# %%
dfArgentina = pd.DataFrame({'Provincia': provincias, "Pobreza": pobreza})

# %%
dfArgentina
# Out:
#               Provincia    Pobreza
# 0          Buenos Aires   8.167798
# 1             Catamarca   9.234095
# 2               Córdoba   5.382380
# 3            Corrientes  12.747191
# 4                 Chaco  15.862619
# 5                Chubut   8.051752
# 6            Entre Ríos   7.288751
# 7               Formosa  17.035583
# 8                 Jujuy  13.367965
# 9              La Pampa   3.398774
# 10             La Rioja  10.875152
# 11              Mendoza   5.692798
# 12             Misiones  13.529788
# 13              Neuquén   9.456635
# 14            Río Negro   8.678391
# 15                Salta  16.870500
# 16             San Juan   9.050784
# 17             San Luis   6.593771
# 18           Santa Cruz   8.024762
# 19             Santa Fe   6.081012
# 20  Santiago del Estero  11.759000
# 21              Tucumán  11.214239

# %%
dfArgentina.sort_values('Pobreza', ascending=False).head(5)
# Out:
#    Provincia    Pobreza
# 7    Formosa  17.035583
# 15     Salta  16.870500
# 4      Chaco  15.862619
# 12  Misiones  13.529788
# 8      Jujuy  13.367965

# %%
dfArgentina.sort_values('Pobreza', ascending=False).tail(5)
# Out:
#    Provincia   Pobreza
# 17  San Luis  6.593771
# 19  Santa Fe  6.081012
# 11   Mendoza  5.692798
# 2    Córdoba  5.382380
# 9   La Pampa  3.398774

# %%
provincias = datos['province']
doctor = datos['doctors_per_cap']

# %%
fArgentina = pd.DataFrame({'Provincia': provincias, "doctores": doctor})

# %%
fArgentina
# Out:
#               Provincia  doctores
# 0          Buenos Aires  0.004836
# 1             Catamarca  0.004502
# 2               Córdoba  0.010175
# 3            Corrientes  0.004495
# 4                 Chaco  0.003605
# 5                Chubut  0.004498
# 6            Entre Ríos  0.004679
# 7               Formosa  0.003440
# 8                 Jujuy  0.003958
# 9              La Pampa  0.005415
# 10             La Rioja  0.005092
# 11              Mendoza  0.005720
# 12             Misiones  0.002880
# 13              Neuquén  0.005067
# 14            Río Negro  0.004898
# 15                Salta  0.003991
# 16             San Juan  0.005044
# 17             San Luis  0.006102
# 18           Santa Cruz  0.004271
# 19             Santa Fe  0.006672
# 20  Santiago del Estero  0.002821
# 21              Tucumán  0.005501

# %%
fArgentina.sort_values('doctores', ascending=False).head(5)
# Out:
#    Provincia  doctores
# 2    Córdoba  0.010175
# 19  Santa Fe  0.006672
# 17  San Luis  0.006102
# 11   Mendoza  0.005720
# 21   Tucumán  0.005501

# %%
fArgentina.sort_values('doctores', ascending=False).tail(5)
# Out:
#               Provincia  doctores
# 8                 Jujuy  0.003958
# 4                 Chaco  0.003605
# 7               Formosa  0.003440
# 12             Misiones  0.002880
# 20  Santiago del Estero  0.002821

# %%
provin_selec = dfArgentina.Provincia.isin(['Córdoba', 'Formosa', 'San Luis', 'Santa Cruz', 'Salta'])

# %%
datos[provin_selec]
# Out:
#       province           gdp  illiteracy    poverty  deficient_infra  \
# 2      Córdoba  6.936374e+07    2.714140   5.382380        10.436086
# 7      Formosa  3.807057e+06    4.610640  17.035583        28.004985
# 15       Salta  1.343883e+07    3.346090  16.870500        14.182303
# 17    San Luis  1.178085e+07    3.433650   6.593771         9.679894
# 18  Santa Cruz  1.166374e+07    0.791485   8.024762         7.411364
#
#     school_dropout  no_healthcare  birth_mortal      pop  \
# 2         1.035056        45.7640           4.8  3308876
# 7         2.268974        65.8126          16.2   530162
# 15        1.482030        60.4230           5.8  1214441
# 17        2.000172        51.6154           3.8   432310
# 18        0.289262        29.2321           3.3   273964
#
#     movie_theatres_per_cap  doctors_per_cap
# 2                 0.000011         0.010175
# 7                 0.000004         0.003440
# 15                0.000004         0.003991
# ...
