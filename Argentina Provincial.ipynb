# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/argentina-provincial-data/argentina.csv

# %%
datos = pd.read_csv('../input/argentina-provincial-data/argentina.csv')

# %%
po = datos.sort_values(by='poverty')

# %%
po.head()
# Out:
#     province           gdp  illiteracy   poverty  deficient_infra  \
# 9   La Pampa  6.990262e+06     1.53930  3.398774        16.505714
# 2    Córdoba  6.936374e+07     2.71414  5.382380        10.436086
# 11   Mendoza  3.343137e+07     2.20020  5.692798         3.839852
# 19  Santa Fe  8.158869e+07     1.97594  6.081012        11.869195
# 17  San Luis  1.178085e+07     3.43365  6.593771         9.679894
#
#     school_dropout  no_healthcare  birth_mortal      pop  \
# 9         0.204093        45.4764           7.2   318951
# 2         1.035056        45.7640           4.8  3308876
# 11        1.063718        50.5843           4.4  1738929
# 19        2.872181        41.9660           2.6  3194537
# 17        2.000172        51.6154           3.8   432310
#
#     movie_theatres_per_cap  doctors_per_cap
# 9                 0.000019         0.005415
# 2                 0.000011         0.010175
# 11                0.000008         0.005720
# ...

# %%
po.tail()
# Out:
#     province           gdp  illiteracy    poverty  deficient_infra  \
# 8      Jujuy  6.484938e+06     2.15139  13.367965        12.483179
# 12  Misiones  9.646826e+06     6.86395  13.529788         8.325740
# 4      Chaco  9.832643e+06     7.51758  15.862619        31.479527
# 15     Salta  1.343883e+07     3.34609  16.870500        14.182303
# 7    Formosa  3.807057e+06     4.61064  17.035583        28.004985
#
#     school_dropout  no_healthcare  birth_mortal      pop  \
# 8         0.721295        54.1615           3.7   673307
# 12        3.129124        57.8339           8.1  1101593
# 4         2.577462        65.5104           7.5  1055259
# 15        1.482030        60.4230           5.8  1214441
# 7         2.268974        65.8126          16.2   530162
#
#     movie_theatres_per_cap  doctors_per_cap
# 8                 0.000003         0.003958
# 12                0.000002         0.002880
# 4                 0.000003         0.003605
# ...

# %%
pa = datos.sort_values(by='doctors_per_cap')

# %%
pa.head(5)
# Out:
#                province           gdp  illiteracy    poverty  deficient_infra  \
# 20  Santiago del Estero  8.387859e+06     6.27209  11.759000        20.491433
# 12             Misiones  9.646826e+06     6.86395  13.529788         8.325740
# 7               Formosa  3.807057e+06     4.61064  17.035583        28.004985
# 4                 Chaco  9.832643e+06     7.51758  15.862619        31.479527
# 8                 Jujuy  6.484938e+06     2.15139  13.367965        12.483179
#
#     school_dropout  no_healthcare  birth_mortal      pop  \
# 20        2.325598        63.6637           1.7   874006
# 12        3.129124        57.8339           8.1  1101593
# 7         2.268974        65.8126          16.2   530162
# 4         2.577462        65.5104           7.5  1055259
# 8         0.721295        54.1615           3.7   673307
#
#     movie_theatres_per_cap  doctors_per_cap
# 20                0.000003         0.002821
# 12                0.000002         0.002880
# ...

# %%
pa.tail(5)
# Out:
#     province           gdp  illiteracy    poverty  deficient_infra  \
# 21   Tucumán  1.385620e+07     3.77037  11.214239         6.466665
# 11   Mendoza  3.343137e+07     2.20020   5.692798         3.839852
# 17  San Luis  1.178085e+07     3.43365   6.593771         9.679894
# 19  Santa Fe  8.158869e+07     1.97594   6.081012        11.869195
# 2    Córdoba  6.936374e+07     2.71414   5.382380        10.436086
#
#     school_dropout  no_healthcare  birth_mortal      pop  \
# 21        0.977285        48.2242           3.0  1448188
# 11        1.063718        50.5843           4.4  1738929
# 17        2.000172        51.6154           3.8   432310
# 19        2.872181        41.9660           2.6  3194537
# 2         1.035056        45.7640           4.8  3308876
#
#     movie_theatres_per_cap  doctors_per_cap
# 21                0.000005         0.005501
# 11                0.000008         0.005720
# 17                0.000005         0.006102
# ...

# %%
juan = datos.loc[datos['province'] == 'Córdoba']
pedro= datos.loc[datos['province'] == 'Formosa']
jaime= datos.loc[datos['province'] == 'San Luis']
jazmin= datos.loc[datos['province'] == 'Santa Cruz']
veroronica= datos.loc[datos['province'] == 'Salta']

# %%
juan
# Out:
#   province           gdp  illiteracy  poverty  deficient_infra  \
# 2  Córdoba  6.936374e+07     2.71414  5.38238        10.436086
#
#    school_dropout  no_healthcare  birth_mortal      pop  \
# 2        1.035056         45.764           4.8  3308876
#
#    movie_theatres_per_cap  doctors_per_cap
# 2                0.000011         0.010175

# %%
jaime
# Out:
#     province           gdp  illiteracy   poverty  deficient_infra  \
# 17  San Luis  1.178085e+07     3.43365  6.593771         9.679894
#
#     school_dropout  no_healthcare  birth_mortal     pop  \
# 17        2.000172        51.6154           3.8  432310
#
#     movie_theatres_per_cap  doctors_per_cap
# 17                0.000005         0.006102

# %%
pedro
# Out:
#   province           gdp  illiteracy    poverty  deficient_infra  \
# 7  Formosa  3.807057e+06     4.61064  17.035583        28.004985
#
#    school_dropout  no_healthcare  birth_mortal     pop  \
# 7        2.268974        65.8126          16.2  530162
#
#    movie_theatres_per_cap  doctors_per_cap
# 7                0.000004          0.00344

# %%
jazmin
# Out:
#       province           gdp  illiteracy   poverty  deficient_infra  \
# 18  Santa Cruz  1.166374e+07    0.791485  8.024762         7.411364
#
#     school_dropout  no_healthcare  birth_mortal     pop  \
# 18        0.289262        29.2321           3.3  273964
#
#     movie_theatres_per_cap  doctors_per_cap
# 18                0.000011         0.004271

# %%
veroronica
# Out:
#    province           gdp  illiteracy  poverty  deficient_infra  \
# 15    Salta  1.343883e+07     3.34609  16.8705        14.182303
#
#     school_dropout  no_healthcare  birth_mortal      pop  \
# 15         1.48203         60.423           5.8  1214441
#
#     movie_theatres_per_cap  doctors_per_cap
# 15                0.000004         0.003991
